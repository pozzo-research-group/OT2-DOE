# %%
from Plan import CreateSamples_renewed
from Prepare import OT2Commands as ALH
from Prepare import OT2Graphing as ographing
from opentrons import simulate, execute, protocol_api
import importlib
import matplotlib.pyplot as plt

# %%
importlib.reload(CreateSamples_renewed)
importlib.reload(ALH)
# Out:
# <module 'Prepare.OT2Commands' from 'C:\\Users\\Edwin\\Desktop\\OT2-DOE\\PlanPrepareProcess\\Prepare\\OT2Commands.py'>

# %%
path = r"Testing Plans\05_7_21_5CB_General_Scan.csv"
chem_path = r"Chemical Database.csv"
plan = CreateSamples_renewed.get_experiment_plan(path, chem_path)

# %%
concentration_df = CreateSamples_renewed.concentration_from_linspace(plan['Component Shorthand Names'], 
                                                                     plan['Component Concentration Linspaces [min, max, n]'],
                                                                     plan['Component Concentration Units'],
                                                                     unity_filter=True,
                                                                     component_spacing_type='linear')

# %%
complete_amounts_added = CreateSamples_renewed.determine_component_amounts(plan, concentration_df, nan_fill_value=0)
stock_dict = CreateSamples_renewed.stock_dictionary(plan['Stock Names'], plan['Stock Concentration Units'], plan['Stock Concentrations'], stock_densities=plan['Stock Densities (g/mL)'])
complete_df = CreateSamples_renewed.calculate_stock_volumes_from_component_concs(plan, complete_amounts_added, stock_dict)
complete_df_solvent_fixed = CreateSamples_renewed.calculate_common_solvent_residual_volumes(complete_df, stock_dict) # be careful with this can subtract more than once
# Out:
# You calculated for component masses given the provided units
# You calculated for component masses given the provided units
# You calculated for component masses given the provided units

# %%
# stock_volumes = CreateSamples_renewed.isolate_common_column(complete_df_solvent_fixed,'stock')
stock_volumes = CreateSamples_renewed.convert_mL_to_uL(complete_df_solvent_fixed)
filtered_stock_volumes = CreateSamples_renewed.filter_general_min_pipette_restriction(stock_volumes, 20)
filtered_stock_volumes = CreateSamples_renewed.filter_general_max_restriction(filtered_stock_volumes, 1000, 'water-stock amount volume uL')
filtered_stock_volumes.reset_index(inplace=True, drop=True)

# %%
labware_dir_path = r"Custom Labware"
custom_labware_dict = ALH.custom_labware_dict(labware_dir_path)
protocol = simulate.get_protocol_api('2.3', extra_labware=custom_labware_dict) # make note this must be run constantly ~ if say making loaded dict twice
loaded_dict = ALH.loading_labware(protocol, plan)
# Out:
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults

# %%
max_source_vol = 18000 # if the list index reports out of range most likely not enough slots aka too much volume
stock_position_info = ALH.stock_well_ranges(filtered_stock_volumes, loaded_dict, max_source_vol) 
stock_position_info
# Out:
# {'5CB-ethanol-stock amount volume uL': {'Ranges': [[0, 44]],
#   'Stock Wells': [A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1]},
#  'ethanol-stock amount volume uL': {'Ranges': [[0, 41], [41, 44]],
#   'Stock Wells': [A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1,
#    A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1]},
#  'water-stock amount volume uL': {'Ranges': [[0, 28], [28, 44]],
#   'Stock Wells': [A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1,
#    B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1]}}

# %%
directions = ALH.create_sample_making_directions(filtered_stock_volumes, stock_position_info, loaded_dict) 
# these directions should be used to make the df, unless there is a final move??

# %%
ALH.pipette_volumes_sample_wise(protocol, directions, loaded_dict)
# Out:
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 126.7427122940431 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 126.7427122940431 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 126.7427122940431 uL into A1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 900.0 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 900.0 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 900.0 uL into A1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 26.990237046518345 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 26.990237046518345 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 26.990237046518345 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 899.75 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 899.75 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 899.75 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 225.32037741163217 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 225.32037741163217 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 225.32037741163217 uL into A3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 822.2222222222222 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 822.2222222222222 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 822.2222222222222 uL into A3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 125.56790216410741 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 125.56790216410741 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 125.56790216410741 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 821.9722222222222 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 821.9722222222222 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 821.9722222222222 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 25.815426916582645 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 25.815426916582645 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 25.815426916582645 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 821.7222222222223 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 821.7222222222223 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 821.7222222222223 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 323.89804252922124 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 323.89804252922124 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 323.89804252922124 uL into A6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 744.4444444444445 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 744.4444444444445 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 744.4444444444445 uL into A6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 224.14556728169646 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 224.14556728169646 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 224.14556728169646 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 744.1944444444445 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 744.1944444444445 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 744.1944444444445 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 124.3930920341717 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 124.3930920341717 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 124.3930920341717 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 743.9444444444446 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 743.9444444444446 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 743.9444444444446 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 24.640616786646973 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 24.640616786646973 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 24.640616786646973 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 743.6944444444445 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 743.6944444444445 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 743.6944444444445 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 422.47570764681035 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 422.47570764681035 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 422.47570764681035 uL into B4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 666.6666666666666 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 666.6666666666666 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 666.6666666666666 uL into B4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into B5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 322.72323239928556 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 322.72323239928556 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 322.72323239928556 uL into B5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 666.4166666666666 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 666.4166666666666 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 666.4166666666666 uL into B5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 222.97075715176084 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 222.97075715176084 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 222.97075715176084 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 666.1666666666666 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 666.1666666666666 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 666.1666666666666 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 123.21828190423612 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 123.21828190423612 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 123.21828190423612 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 665.9166666666667 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 665.9166666666667 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 665.9166666666667 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 23.46580665671133 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 23.46580665671133 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 23.46580665671133 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 665.6666666666666 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 665.6666666666666 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 665.6666666666666 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 521.0533727643993 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 521.0533727643993 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 521.0533727643993 uL into C3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 588.8888888888889 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 588.8888888888889 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 588.8888888888889 uL into C3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 421.3008975168746 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 421.3008975168746 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 421.3008975168746 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 588.6388888888889 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 588.6388888888889 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 588.6388888888889 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 321.5484222693498 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 321.5484222693498 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 321.5484222693498 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 588.3888888888888 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 588.3888888888888 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 588.3888888888888 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 221.7959470218251 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 221.7959470218251 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 221.7959470218251 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 588.138888888889 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 588.138888888889 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 588.138888888889 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 122.0434717743003 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 122.0434717743003 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 122.0434717743003 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 587.8888888888889 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 587.8888888888889 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 587.8888888888889 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 619.6310378819885 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 619.6310378819885 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 619.6310378819885 uL into D2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 511.1111111111111 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 511.1111111111111 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 511.1111111111111 uL into D2 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into D3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 519.8785626344637 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 519.8785626344637 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 519.8785626344637 uL into D3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 510.8611111111111 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 510.8611111111111 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 510.8611111111111 uL into D3 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into D4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 420.12608738693893 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 420.12608738693893 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 420.12608738693893 uL into D4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 510.61111111111114 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 510.61111111111114 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 510.61111111111114 uL into D4 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into D5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 320.3736121394142 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 320.3736121394142 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 320.3736121394142 uL into D5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 510.36111111111103 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 510.36111111111103 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 510.36111111111103 uL into D5 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into D6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 220.62113689188945 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 220.62113689188945 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 220.62113689188945 uL into D6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 510.1111111111111 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Fischer 24 Well Plate 7400 ÂµL on 2
# Aspirating 510.1111111111111 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 510.1111111111111 uL into D6 of Fischer 24 Well Plate 7400 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 718.2087029995776 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 718.2087029995776 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 718.2087029995776 uL into A1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 433.33333333333337 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 433.33333333333337 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 433.33333333333337 uL into A1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 618.4562277520528 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 618.4562277520528 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 618.4562277520528 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 433.08333333333337 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 433.08333333333337 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 433.08333333333337 uL into A2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into A3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 518.703752504528 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 518.703752504528 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 518.703752504528 uL into A3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 432.8333333333334 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 432.8333333333334 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 432.8333333333334 uL into A3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 418.95127725700326 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 418.95127725700326 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 418.95127725700326 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 432.5833333333333 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 432.5833333333333 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 432.5833333333333 uL into A4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 319.19880200947847 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 319.19880200947847 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 319.19880200947847 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 432.33333333333337 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 432.33333333333337 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 432.33333333333337 uL into A5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 816.7863681171666 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 816.7863681171666 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 816.7863681171666 uL into A6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 355.5555555555555 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 355.5555555555555 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 355.5555555555555 uL into A6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 717.0338928696419 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 717.0338928696419 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 717.0338928696419 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 355.30555555555554 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 355.30555555555554 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 355.30555555555554 uL into B1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 617.281417622117 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 617.281417622117 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 617.281417622117 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 355.05555555555554 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 355.05555555555554 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 355.05555555555554 uL into B2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 517.5289423745924 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 517.5289423745924 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 517.5289423745924 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 354.8055555555555 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 354.8055555555555 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 354.8055555555555 uL into B3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into B4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 417.77646712706763 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 417.77646712706763 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 417.77646712706763 uL into B4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 354.5555555555555 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 354.5555555555555 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 354.5555555555555 uL into B4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 915.3640332347555 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 915.3640332347555 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 915.3640332347555 uL into B5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 277.77777777777777 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 277.77777777777777 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 277.77777777777777 uL into B5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 815.6115579872309 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 815.6115579872309 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 815.6115579872309 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 277.5277777777778 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 277.5277777777778 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 277.5277777777778 uL into B6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 715.859082739706 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 715.859082739706 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 715.859082739706 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 277.2777777777778 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 277.2777777777778 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 277.2777777777778 uL into C1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 616.1066074921813 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 616.1066074921813 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 616.1066074921813 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 277.02777777777777 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 277.02777777777777 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 277.02777777777777 uL into C2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into C3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 516.3541322446565 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 516.3541322446565 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 516.3541322446565 uL into C3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 276.77777777777777 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 276.77777777777777 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 276.77777777777777 uL into C3 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 1013.9416983523448 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 506.9708491761724 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 506.9708491761724 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Aspirating 506.9708491761724 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 506.9708491761724 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 199.99999999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 199.99999999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 199.99999999999994 uL into C4 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 100.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 100.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 100.0 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 914.1892231048201 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 914.1892231048201 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 914.1892231048201 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 199.74999999999997 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 199.74999999999997 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 199.74999999999997 uL into C5 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 200.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 200.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 200.0 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 814.4367478572954 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 814.4367478572954 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 814.4367478572954 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 199.5 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 199.5 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 199.5 uL into C6 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 300.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 300.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 300.0 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 714.6842726097707 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 714.6842726097707 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 714.6842726097707 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 199.24999999999991 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 199.24999999999991 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 199.24999999999991 uL into D1 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 400.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 400.0 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 400.0 uL into D2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 614.9317973622458 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 614.9317973622458 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 614.9317973622458 uL into D2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 198.99999999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Fischer 24 Well Plate 7400 ÂµL on 3
# Aspirating 198.99999999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 198.99999999999994 uL into D2 of Fischer 24 Well Plate 7400 ÂµL on 3 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
