# %%
import numpy as np
import pandas as pd
from Plan import CreateSamples as create

# %%
path1 = r"C:\Users\Edwin\Desktop\OT2-DOE\PlanPrepareProcess\Temp or Working\06_03_21_5CB_SDS_Blanked"
full_data = pd.read_csv(path1)
full_data['Total Volume uL'] = create.isolate_common_column(full_data, 'stock').sum(axis=0)
fu

# %%
create.isolate_common_column(full_data, '')
# Out:
#     ethanol concentration wtf  ethanol amount mass g  \
# 0                         0.1                  0.065
# 1                         0.2                  0.130
# 2                         0.3                  0.195
# 3                         0.4                  0.260
# 4                         0.5                  0.325
# ..                        ...                    ...
# 92                        0.4                  0.260
# 93                        0.5                  0.325
# 94                        0.6                  0.390
# 95                        0.7                  0.455
# 96                        0.8                  0.520
#
#     ethanol amount volume uL  5CB-ethanol-stock amount volume uL  \
# 0                  82.351451                                65.0
# 1                 164.702901                                65.0
# 2                 247.054352                                65.0
# 3                 329.405803                                65.0
# 4                 411.757253                                65.0
# ..                       ...                                 ...
# 92                329.405803                               260.0
# 93                411.757253                               260.0
# 94                494.108704                               260.0
# 95                576.460155                               260.0
# 96                658.811605                               260.0
#
#     SDS-ethanol-stock amount volume uL  ethanol-stock amount volume uL
# 0                             0.000000                       99.717853
# 1                             0.000000                      264.274815
# 2                             0.000000                      428.831777
# 3                             0.000000                      593.388739
# 4                             0.000000                      757.945701
# ..                                 ...                             ...
# 92                          185.714286                      213.478909
# 93                          185.714286                      378.035871
# 94                          185.714286                      542.592833
# 95                          185.714286                      707.149795
# 96                          185.714286                      871.706757
#
# [97 rows x 6 columns]
