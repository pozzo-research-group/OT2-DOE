# %% [markdown]
# # This notebook serves as walkthrough for planning an experiment for creation through the OT2.
# ### The following modules are used and should be in the same directory as this notebook:
# * **CreateSamples** is responsible for calculating sample information, which includes component weight fractions and stock volumes
# * **OT2Commands** is responsible for setting up information to be interpretted and executed by opentrons.
# * **OT2Graphing** contains graphing tools to help visualize and explore parameter spaces.

# %%
from Plan import CreateSamples
from Prepare import OT2Commands as ALH
from Prepare import OT2Graphing as ographing
from opentrons import simulate, execute, protocol_api

import importlib

# %% [markdown]
# ### Step 1: Set up the experiment dictionary.
# The first step to planning an experiment is to load the experiment variables and inputs from a csv file. Every variable should have an input with an acceptable datatype. At the moment this step is done by opening a CSV file in Excel, where the first column is the name of the variable and the adjacent column is the variable value. The default delimitter is (,).
#
# The experiment dictionary consist of keys being the variable name and the value being the variables value. It is important to always keep in mind the order of every variable is linear and should be assumed to be match all other variables (i.e. Component Shorthand Names index 1 = Component Concentration index 1). This assumption is the default for any function using variables from the experiment dictionary, however we can deviate it from it if needed.
#
# Note: Most functions will rely on static variable names from the dict (i.e. dict['name']).

# %%
experiment_plan_path = r"C:\Users\Edwin\Desktop\OT2-DOE\PlanPrepareProcess\Testing Plans\04_07_21_Ouzo_Saturated_PFO.csv"
plan = CreateSamples.get_experiment_plan(experiment_plan_path)

# %% [markdown]
# ### Step 2: Select and Create Sampling Space
# Create sampling space using information is pulled from the experimental dictionary made in Step 1.
#
# The sampling method will mainly depend on the type of sample units and the actual called method (i.e. lattic, non-clustering random..etc).
#
# Currently the only sampling method available are simple lattice and random based sampling through the *CreateSamples.generate_candidate_lattice_concentrations* function. There are two potential ways to create samples in a system of n components which currently utilzie the linspaces of concentration [minimum concentration, maximum concentration, number of samples].
# 1. **Case 1 (Completing case):** Specify all but one (in this case the last) component's concentrations, which with the addition of exposing the unity_filter = True, would calculate the the remaining concentraiton values using the information of the last index of all component related variables (i.e. names). This is only meant for units that require unity like volf, wtf, and molf.
# 2. **Case 2 (Non-completing case):** Specify all concentration linspaces, not applying any unit based filters, meant for all other non interdependent units like molarity and mg/mL.
#
# Other things to take into consideration: All units must be the same for unity based, but not for non-unity units. Currently out of caution the available units are hardcoded into the function and this applies to most current functions.

# %%
concentration_canidates = CreateSamples.generate_candidate_lattice_concentrations(plan, unity_filter=True)
concentration_canidates
# Out:
#      dppc concentration wtf  dspepeg200 concentration wtf  \
# 0                  0.000075                      0.000035
# 1                  0.000075                      0.000035
# 2                  0.000075                      0.000035
# 3                  0.000075                      0.000035
# 4                  0.000075                      0.000035
# ..                      ...                           ...
# 495                0.000075                      0.000035
# 496                0.000075                      0.000035
# 497                0.000075                      0.000035
# 498                0.000075                      0.000035
# 499                0.000075                      0.000035
#
#      pfh concentration wtf  ethanol concentration wtf  water concentration wtf
# 0                     0.00                   0.000000                 0.999890
# 1                     0.00                   0.036842                 0.963048
# 2                     0.00                   0.073684                 0.926206
# 3                     0.00                   0.110526                 0.889364
# 4                     0.00                   0.147368                 0.852522
# ..                     ...                        ...                      ...
# 495                   0.01                   0.552632                 0.437258
# 496                   0.01                   0.589474                 0.400416
# 497                   0.01                   0.626316                 0.363574
# 498                   0.01                   0.663158                 0.326732
# 499                   0.01                   0.700000                 0.289890
#
# [500 rows x 5 columns]

# %% [markdown]
# ### Step 3: Calculate Volumes of Stocks
# From the concentration values calculated in Step 2, we use those along with stock concentration information to calculate the volume of required for each sample.
# * This is where things get less "*general*" each case depending on the number of stocks, common components (i.e. component A in both stock A and B) and other requirements will typically require its own function. Luckily given the commmonality of using data frames this should be quite simple.
#     * Currently the only function to calculate volumes in centered around the Ouzo emulsion systems. This system consist of 3 stocks with the solvent being ethanol and two pure stocks of ethanol and water = *CreateSamples.calculate_ouzo_volumes_from_wtf*
#     * To identify solutes and solvents in stock the notation of stock is solute1-solute2-.....-soluten-solvent.

# %%
volume_canidates = CreateSamples.calculate_ouzo_volumes_from_wtf(concentration_canidates, plan)

# %% [markdown]
# ### Step 4: Apply Filters or Other Selection Criteria
#
# It is essential to combine both the concentration and volume dataframes made in Step 2 and 3 into one dataframe such that when we apply filters we apply it all samples values. We do this through the *CreateSamples.combine_df_hotdog* function.
#
# **Filters**: The types of filters can be added easily through dataframe logic. For example, ones in the CreateSamples module:
#    * *pipette_volume_restriction_df* = Given the lower and upper ranges of the two sets of pipettes you will use to synthesize the samples, will remove anything not in range or zero.
#    * *total_volume_restriction_df* = Restrict total volume, mostly based on labware constraints. Column selection based on "total".
#    * *general_max_restriction_df* = provide max value and column name
#    * *general_min_restriction_df* = provide min value and column name
#
# **Other Selection Critera**
#    * *.multiplydf(n, df)* = Will multiply a data frame by n number of times. Useful when making one sample repeatadly.
#    * a specfic concentration or volume

# %%
complete_df_unfiltered = CreateSamples.combine_df_hotdog(concentration_canidates, volume_canidates)
complete_df_filtered = CreateSamples.pipette_volume_restriction_df(complete_df_unfiltered, 20, 1000, ['N', 'N', 'N', 'N', 'Y'])
complete_df_filtered = CreateSamples.total_volume_restriction_df(complete_df_filtered, 1500)

# %% [markdown]
# ### Step 4a (Optional): Visual
# If you would like, you can visual the space you are sampling by calling up to 3 columns of interest from the componsitional space. The module OT2Graphing will contain helpful function to visualize the sampling space.
# * Note: Given limitation with adding packages to OT2, anything utilziing matplotlib will not work on the OT2's native jupyter notebook. This is currently the only module which references it.

# %%
ographing.xy_scatter_df_compare(complete_df_unfiltered, complete_df_filtered, 'ethanol concentration wtf', 'pfh concentration wtf')

# %% [markdown]
# ### Step 5: Addition of Blanks/Standards
# The most accurate way to blank samples or compare to standards is to create a sample without components of interest for every sample made in the prior dataframes.
#
# The most straightforward way of doing this is by calling which columns you will be removing/zeroing out. If concentration units are non-unity (i.e. mg/mL or molarity) thats it. If unity based (volf, molf...) then you will need to take that removed value and add to to another component. Finally, recalculate volumes like you did in Step 3.
# * Following this will make a blank for each sample which can be wasteful, so filter for duplicates.
# * You may need to filter based on volume again depending on your protocol/system as volumes will change slightly for each component.
#
# Note: If unity completing option used in Step 1 then add to that completing component.

# %%
remove_components = ['dppc concentration wtf', 'dspepeg200 concentration wtf', 'pfh concentration wtf']
add_to = 'water concentration wtf'  


blanked_compositions = CreateSamples.blank_sum_to_end(complete_df_filtered, remove_components, add_to)
blanked_compositions_nondup = CreateSamples.remove_duplicates(blanked_compositions, 3)
blank_volumes = CreateSamples.calculate_ouzo_volumes_from_wtf(blanked_compositions_nondup, plan)
blank_complete_df = CreateSamples.combine_df_hotdog(blanked_compositions_nondup, blank_volumes)

# %% [markdown]
# ## Step 6: Finalize and Call Seperate Concentration and Volume Dataframes
# Now that we have made the appropiate complete sample and blank dataframes we are to combine them into one for better handling. Afterwards we seperate the entirely new and final dataframe on the basis of concentration and stock volume unit.
# *We seperate to allow for easier handiling of creating a final dataframe for exporting and reporting volumes to the OT2 for execution/simulation.*

# %%
final_complete_df = CreateSamples.combine_df_hamburger(complete_df_filtered, blank_complete_df)
final_composition_df = CreateSamples.isolate_common_column(final_complete_df, 'concentration')
final_volume_df = CreateSamples.isolate_common_column(final_complete_df, 'stock')

# %% [markdown]
# ### Step 6 (Optional): Calculate Stock Prep Information
#
# We can calculate stock information to make it easier to prepare these stock. This process if semi-general, currently supporting a few stock concentration units = mgperml, volf, wtf, molf and molarity. All of these require the basis of volume as that is what is driving how much sample we make for the OT2.
#
# The logic behind this relies on the notation of stocks = solute1-solute2-....solvent. Using notations allows for systematic handling of solutes and solvent determining what is needed based on information from a excel based Chemical Database.
#
# *Reccomended*: Use at the minimum the default buffering (extra stock being made) of 40 percent to ensure you do not aspirate any air by mistake.

# %%
chem_database_path = r"Chemical Database.xlsx"
stock_prep_df = CreateSamples.calculate_stock_prep_df(plan, final_volume_df, chem_database_path, buffer_pct=50)
stock_prep_df
# Out:
#                   dppc-ethanol-stock  L  dspepeg2000-ethanol-stock  L  \
# solute mass g                  0.008640                      0.004010
# solute volume L                0.000000                      0.000000
# solvent mass g                 3.409776                      3.781213
# solvent volume L               0.004320                      0.004791
#
#                   pfh-ethanol-stock  L  ethanol-stock  L  water-stock  L
# solute mass g                 0.149053          0.000000        0.000000
# solute volume L               0.000088          0.000000        0.000000
# solvent mass g               14.756233         24.967479       69.831975
# solvent volume L              0.018695          0.031632        0.069832

# %% [markdown]
# ### Step 8: Simulate/Execute
# * The main information needed to create commands for the OT2 is the position of the stocks and the volumes in respect to each well you would like to move the stock to. All volumes in sent to the OT2 will be interpretted as microliters (uL).
#     * Stock Volumes: We have calculated this in step 3. The way we prepare these samples can vary, which is what were refer to as the *pipetteing strategy*.
#         * Pipetting Strategy 1: Add each stock to all wells then move onto next stock. The upside to this is the simplicity of the written protocol. It has a downside of using more tips. It can allow for evaporation or other time sensitve process to occur in the time between stock additions.
#         * Pipetting Strategy 2: Adding all stocks to a well then moving on.

# %% [markdown]
# ### Step 8a Optional: Load custom labware dictionary (Remote Testing)
# * Provide the path to the directory holding all custom labware. This directory should have custom labware .json files you have previously made and tested, read more here: https://support.opentrons.com/en/articles/3136504-creating-custom-labware-definitions
# * The reason we provide this is when working on a device that is not connected to the OT2's Jupyter notebook there is no way to natively use custom labware. So we create a dictionary of custom labware so we can later load into our protocol to primarily simualte and test protocols for execution later once connnected to the OT2's notebook.
#     * When using custom labware on the OT2's notebook it pulls from a folder labeled "labware", which is something built into the Opentrons hardware. It has not been tested if the custom labware dictionary will superceed this directory of custom labware if used on the OT2.
#     * The custom labware folder should contain everything the OT2 labware folder contains: ADD GDRIVE link to customize
#
# * **NOTE: Any function using the custom_labware_dict, the argument is optional so can remove and should receive same output IF working on OT2 computer.**
#
# Just noted: transfer_info will fail if transfer and distribute used together, well not fail jsut need to concat

# %%
labware_dir_path = r"Custom Labware"
custom_labware_dict = ALH.custom_labware_dict(labware_dir_path)
importlib.reload(ALH)
# Out:
# <module 'Prepare.OT2Commands' from 'C:\\Users\\Edwin\\Desktop\\OT2-DOE\\PlanPrepareProcess\\Prepare\\OT2Commands.py'>

# %% [markdown]
# ### Set up Loaded Dictionary and Directions for Volume Handling
# It is important to know how many stock container will be needed for each stock and be able to provide the correct instructions for OT2 commands to follow.
#
# The ranges of stock refers to the ranges of wells one stock will cover. The range is provided in terms of the index of the stock volume dataframe i.e.([lower, upper])). The format is as follows = [[stock1_range1, stock1_range2....], [stock2_range1, stock2_range2....] []...].
#
# The basis of range is on the maximum volume of the stock container, however currently limitation are:
#  * All stock containers must be the same
#  * Each component must have its own stock - need to test verify

# %%
protocol = simulate.get_protocol_api('2.2', extra_labware=custom_labware_dict)
loaded_dict = ALH.loading_labware(protocol, plan)
loaded_dict = ALH.determine_pipette_resolution(loaded_dict) # this should just be automatically called move into function
max_source_vol = 15000
stock_position_info = ALH.stock_well_ranges(loaded_dict, final_volume_df, max_source_vol)
# Out:
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults

# %%
directions = ALH.create_sample_making_directions(final_volume_df, stock_position_info, loaded_dict)
transfer_info = ALH.pipette_volumes_sample_wise(protocol, directions, loaded_dict)
# Out:
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 23.54352623826038 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 23.54352623826038 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 23.54352623826038 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 711.4909473684211 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 711.4909473684211 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 711.4909473684211 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 51.87981714362404 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 51.87981714362404 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 51.87981714362404 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 682.0172631578948 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 682.0172631578948 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 682.0172631578948 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 79.87761830469981 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 79.87761830469981 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 79.87761830469981 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 652.5435789473685 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 652.5435789473685 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 652.5435789473685 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 107.51253111310503 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 107.51253111310503 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 107.51253111310503 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 623.0698947368421 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 623.0698947368421 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 623.0698947368421 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 134.75954273516103 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 134.75954273516103 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 134.75954273516103 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 593.5962105263159 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 593.5962105263159 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 593.5962105263159 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 161.5933344455735 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 161.5933344455735 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 161.5933344455735 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 564.1225263157895 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 564.1225263157895 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 564.1225263157895 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 187.98858996111292 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 187.98858996111292 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 187.98858996111292 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 534.6488421052632 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 534.6488421052632 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 534.6488421052632 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 213.92030377429535 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 213.92030377429535 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 213.92030377429535 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 505.17515789473686 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 505.17515789473686 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 505.17515789473686 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 239.36408948706247 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 239.36408948706247 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 239.36408948706247 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 475.70147368421055 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 475.70147368421055 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 475.70147368421055 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 264.29648814446216 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 264.29648814446216 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 264.29648814446216 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 446.22778947368437 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 446.22778947368437 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 446.22778947368437 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 288.69527656832963 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 288.69527656832963 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 288.69527656832963 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 416.75410526315795 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 416.75410526315795 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 416.75410526315795 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 312.5397756909667 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 312.5397756909667 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 312.5397756909667 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 387.2804210526316 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 387.2804210526316 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 387.2804210526316 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 335.8111588888234 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 335.8111588888234 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 335.8111588888234 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 357.8067368421053 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 357.8067368421053 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 357.8067368421053 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 358.49276031617796 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 358.49276031617796 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 358.49276031617796 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 328.333052631579 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 328.333052631579 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 328.333052631579 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 380.5703832388172 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 380.5703832388172 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 380.5703832388172 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 298.85936842105264 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 298.85936842105264 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 298.85936842105264 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 402.0326083677173 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 402.0326083677173 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 402.0326083677173 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 269.38568421052634 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 269.38568421052634 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 269.38568421052634 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 422.87110219272404 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 422.87110219272404 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 422.87110219272404 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 239.912 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 239.912 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 239.912 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 37.88312627609877 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 37.88312627609877 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 37.88312627609877 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 652.2102456140351 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 652.2102456140351 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 652.2102456140351 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 65.51803908450398 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 65.51803908450398 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 65.51803908450398 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 622.7365614035089 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 622.7365614035089 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 622.7365614035089 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 92.76505070655999 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 92.76505070655999 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 92.76505070655999 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 593.2628771929824 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 593.2628771929824 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 593.2628771929824 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 119.59884241697247 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 119.59884241697247 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 119.59884241697247 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 563.7891929824563 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 563.7891929824563 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 563.7891929824563 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 145.9940979325119 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 145.9940979325119 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 145.9940979325119 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 534.3155087719298 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 534.3155087719298 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 534.3155087719298 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# ...
# Transferring 276.8946391895221 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 276.8946391895221 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 276.8946391895221 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 505.6 from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 505.6 uL from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 505.6 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 302.4521214773651 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 302.4521214773651 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 302.4521214773651 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 476.0 from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 476.0 uL from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 476.0 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 327.493989843896 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 327.493989843896 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 327.493989843896 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 446.4000000000001 from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 446.4000000000001 uL from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 446.4000000000001 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 351.9977274578703 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 351.9977274578703 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 351.9977274578703 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 416.80000000000007 from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 416.80000000000007 uL from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 416.80000000000007 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 375.94238734347766 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 375.94238734347766 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 375.94238734347766 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 387.2 from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 387.2 uL from B4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 387.2 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 399.3089073780474 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 399.3089073780474 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 399.3089073780474 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 357.6 from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 357.6 uL from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 357.6 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 421.4729321787027 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 421.4729321787027 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 421.4729321787027 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 328.79999999999995 from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 328.79999999999995 uL from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 328.79999999999995 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 443.6517343244005 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 443.6517343244005 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 443.6517343244005 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 299.20000000000005 from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 299.20000000000005 uL from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 299.20000000000005 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 465.2099407013967 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 465.2099407013967 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 465.2099407013967 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 269.6 from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 269.6 uL from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 269.6 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 486.1390894391876 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 486.1390894391876 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 486.1390894391876 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 240.0 from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 5
# Aspirating 240.0 uL from C1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 240.0 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10

# %%
transfer_info = ALH.transfer_from_destination_to_final(protocol, loaded_dict, plan, len(final_volume_df))
# Out:
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 23.54352623826038 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 23.54352623826038 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 23.54352623826038 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 711.4909473684211 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 711.4909473684211 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 711.4909473684211 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 51.87981714362404 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 51.87981714362404 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 51.87981714362404 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 682.0172631578948 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 682.0172631578948 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 682.0172631578948 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 79.87761830469981 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 79.87761830469981 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 79.87761830469981 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 652.5435789473685 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 652.5435789473685 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 652.5435789473685 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 107.51253111310503 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 107.51253111310503 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 107.51253111310503 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 623.0698947368421 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 623.0698947368421 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 623.0698947368421 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 134.75954273516103 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 134.75954273516103 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 134.75954273516103 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 593.5962105263159 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 593.5962105263159 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 593.5962105263159 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 161.5933344455735 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 161.5933344455735 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 161.5933344455735 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 564.1225263157895 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 564.1225263157895 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 564.1225263157895 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 187.98858996111292 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 187.98858996111292 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 187.98858996111292 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 534.6488421052632 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 534.6488421052632 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 534.6488421052632 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 213.92030377429535 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 213.92030377429535 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 213.92030377429535 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 505.17515789473686 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 505.17515789473686 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 505.17515789473686 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 239.36408948706247 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 239.36408948706247 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 239.36408948706247 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 475.70147368421055 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 475.70147368421055 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 475.70147368421055 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 264.29648814446216 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 264.29648814446216 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 264.29648814446216 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 446.22778947368437 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 446.22778947368437 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 446.22778947368437 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 288.69527656832963 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 288.69527656832963 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 288.69527656832963 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 416.75410526315795 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 416.75410526315795 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 416.75410526315795 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 312.5397756909667 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 312.5397756909667 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 312.5397756909667 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 387.2804210526316 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 387.2804210526316 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 387.2804210526316 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 335.8111588888234 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 335.8111588888234 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 335.8111588888234 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 357.8067368421053 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 357.8067368421053 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 357.8067368421053 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 358.49276031617796 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 358.49276031617796 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 358.49276031617796 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 328.333052631579 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 328.333052631579 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 328.333052631579 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 380.5703832388172 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 380.5703832388172 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 380.5703832388172 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 298.85936842105264 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 298.85936842105264 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 298.85936842105264 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 402.0326083677173 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 402.0326083677173 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 402.0326083677173 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 269.38568421052634 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 269.38568421052634 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 269.38568421052634 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 422.87110219272404 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 422.87110219272404 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 422.87110219272404 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 239.912 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 239.912 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 239.912 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 37.88312627609877 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 37.88312627609877 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 37.88312627609877 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 652.2102456140351 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 652.2102456140351 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 652.2102456140351 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 65.51803908450398 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 65.51803908450398 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 65.51803908450398 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 622.7365614035089 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 622.7365614035089 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 622.7365614035089 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 92.76505070655999 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 92.76505070655999 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 92.76505070655999 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 593.2628771929824 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 593.2628771929824 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 593.2628771929824 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 119.59884241697247 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 119.59884241697247 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 119.59884241697247 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 563.7891929824563 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 563.7891929824563 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 563.7891929824563 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 30.000001741800098 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 30.000001741800098 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 30.000001741800098 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 33.267985504663464 from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 33.267985504663464 uL from A2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 33.267985504663464 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 42.194092827004226 from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 42.194092827004226 uL from A3 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 42.194092827004226 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A3 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 145.9940979325119 from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 145.9940979325119 uL from A4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 50.0 uL/sec
# Dispensing 145.9940979325119 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Returning tip
# Dropping tip into A4 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 534.3155087719298 from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 2
# Aspirating 534.3155087719298 uL from B2 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 534.3155087719298 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 1000.0 uL/sec
# Returning tip
# Dropping tip into A5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# ...
# Aspirating 300.0 uL from D1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G1 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D2 of Falcon 48 Well Plate 1500 ÂµL on 3 to G2 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from G10 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G2 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D3 of Falcon 48 Well Plate 1500 ÂµL on 3 to G3 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from H10 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G3 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D4 of Falcon 48 Well Plate 1500 ÂµL on 3 to G4 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from A11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G4 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D5 of Falcon 48 Well Plate 1500 ÂµL on 3 to G5 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from B11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G5 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D6 of Falcon 48 Well Plate 1500 ÂµL on 3 to G6 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from C11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G6 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D7 of Falcon 48 Well Plate 1500 ÂµL on 3 to G7 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from D11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G7 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from D8 of Falcon 48 Well Plate 1500 ÂµL on 3 to G8 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from E11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from D8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G8 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E1 of Falcon 48 Well Plate 1500 ÂµL on 3 to G9 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from F11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G9 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E2 of Falcon 48 Well Plate 1500 ÂµL on 3 to G10 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from G11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E3 of Falcon 48 Well Plate 1500 ÂµL on 3 to G11 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from H11 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E4 of Falcon 48 Well Plate 1500 ÂµL on 3 to G12 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from A12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E5 of Falcon 48 Well Plate 1500 ÂµL on 3 to H1 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from B12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H1 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E6 of Falcon 48 Well Plate 1500 ÂµL on 3 to H2 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from C12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H2 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E7 of Falcon 48 Well Plate 1500 ÂµL on 3 to H3 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from D12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H3 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from E8 of Falcon 48 Well Plate 1500 ÂµL on 3 to H4 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from E12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from E8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H4 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F1 of Falcon 48 Well Plate 1500 ÂµL on 3 to H5 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from F12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from F1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H5 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F2 of Falcon 48 Well Plate 1500 ÂµL on 3 to H6 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from G12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from F2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H6 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F3 of Falcon 48 Well Plate 1500 ÂµL on 3 to H7 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from H12 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 300.0 uL from F3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H7 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F4 of Falcon 48 Well Plate 1500 ÂµL on 3 to H8 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from F4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H8 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F5 of Falcon 48 Well Plate 1500 ÂµL on 3 to H9 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from B1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from F5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H9 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F6 of Falcon 48 Well Plate 1500 ÂµL on 3 to H10 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from C1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from F6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F7 of Falcon 48 Well Plate 1500 ÂµL on 3 to H11 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from D1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from F7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from F8 of Falcon 48 Well Plate 1500 ÂµL on 3 to H12 of Corning 96 Well Plate 360 µL Flat on 6
# Picking up tip from E1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from F8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 123.0 uL/sec
# Dispensing 300.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on 6 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A1 of Falcon 48 Well Plate 1500 ÂµL on 5 to A1 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from F1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A1 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A2 of Falcon 48 Well Plate 1500 ÂµL on 5 to A2 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from G1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A3 of Falcon 48 Well Plate 1500 ÂµL on 5 to A3 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from H1 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A4 of Falcon 48 Well Plate 1500 ÂµL on 5 to A4 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A5 of Falcon 48 Well Plate 1500 ÂµL on 5 to A5 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from B2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A6 of Falcon 48 Well Plate 1500 ÂµL on 5 to A6 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from C2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A7 of Falcon 48 Well Plate 1500 ÂµL on 5 to A7 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from D2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from A8 of Falcon 48 Well Plate 1500 ÂµL on 5 to A8 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from E2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from A8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B1 of Falcon 48 Well Plate 1500 ÂµL on 5 to A9 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from F2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B2 of Falcon 48 Well Plate 1500 ÂµL on 5 to A10 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from G2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B3 of Falcon 48 Well Plate 1500 ÂµL on 5 to A11 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from H2 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B4 of Falcon 48 Well Plate 1500 ÂµL on 5 to A12 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B5 of Falcon 48 Well Plate 1500 ÂµL on 5 to B1 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from B3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into B1 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B6 of Falcon 48 Well Plate 1500 ÂµL on 5 to B2 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from C3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into B2 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B7 of Falcon 48 Well Plate 1500 ÂµL on 5 to B3 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from D3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into B3 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from B8 of Falcon 48 Well Plate 1500 ÂµL on 5 to B4 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from E3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from B8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into B4 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 300.0 from C1 of Falcon 48 Well Plate 1500 ÂµL on 5 to B5 of Corning 96 Well Plate 360 µL Flat on 9
# Picking up tip from F3 of Opentrons 96 Tip Rack 300 µL on 7
# Aspirating 300.0 uL from C1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 123.0 uL/sec
# Dispensing 300.0 uL into B5 of Corning 96 Well Plate 360 µL Flat on 9 at 51.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12

# %% [markdown]
# ### Step 9: Format for Exporting and Upload to Google Drive
# * Using the information from our previously created dataframes we create a final dataframe to convert to a csv and upload to google drive for storage.
#     * Currently the two main pieces of information uploaded are composition of sample and sample location information. This for each sample is tied to a unique ID which contains a well_timestamp_keyword.
#
# * Currently the function *CreateSamples.create_df* uses information from *ALH.pipette_stock_volumes* along with the values of the composition dataframe and experiment dict to create a final df for exporting. It is not super general so will work on seperating the information slicing and dataframe combination - its quite tangeled and needs to be generalized.
#
# * Once you create your dataframe (where every row/index = one unique sample) then we can convert it to a csv and upload to google drive/store.

# %%
export_df = CreateSamples.create_df(transfer_info, final_composition_df.values, plan, unique_identifier='Right')
export_df = CreateSamples.combine_df_hotdog(export_df, final_volume_df)

# %%
temp_hold_path = r"Hold_Info"
export_df.to_csv(temp_hold_path, index=False)

# %% [markdown]
# ### Navigate/Create (to) respective folder on Google Drive
# 1. Call an instance of your google drive, this is statically the Pozzo Team Drive using *CreateSamples.team_drive_dict()*. This should open a new window prompting you for credentials. It will also return a dictionary of the highest level folders name and unique ID. **The unique ID is what will let you navigate**
# 2. Once inside the Team Drive use *CreateSamples.file_and_folder_navi(unique_ID)* by selecting a certain root level folder from step 1. Then you can keep repeating this until you reach the level/directory of interest.
#     * A way to bypass this is to log into google drive and find the unique ID manually EXPLAIN
# 3. Once you have reached the level of interest, create the folder if necessary.
# 4. With the folder ID of interest then use *upload_to_team_drive_folder* providing the path and name of file along with final destination (the ID you found/made from step 2/3). This will upload the respective files to that level.
# 5. Cry
#
#
#
#
# * Add the option to create a new folder - as a function to the package.
# * looks like OT2 can not at all upload any sort of package - so will need to make it clear to only use the drive portion of package on remote computer - hence why we should switch to using the module and having notebooks ayt surface level.

# %%
from Prepare import UploadDrive
importlib.reload(UploadDrive)

# %%
UploadDrive.initialize_connection(r"C:\Users\Edwin\Desktop\OT2creds.txt")

# %%
UploadDrive.team_drive_dict(r"C:\Users\Edwin\Desktop\OT2creds.txt")

# %%
current_members = UploadDrive.file_and_folder_navi('1dXYmxuESNhgmVHntEf8hnZmjK0Br8b64')
# UploadDrive.file_and_folder_navi('1CDnoLE32bG0BFhhvCl5JlRFO4I_ga-eJ')

# %%
plan_file_path = experiment_plan_path
synthesis_info_file_path = r"sample_info"
folder_to_place_id = '1YdAqr1kYFEuRc8wyd9dcyzo0BWW68-1P'

# CreateSamples.upload_to_team_drive_folder(folder_to_place_id, plan_file_path, 'Experiment Plan Info')
CreateSamples.upload_to_team_drive_folder(folder_to_place_id, synthesis_info_file_path, 'Experiment Synthesis Info')
