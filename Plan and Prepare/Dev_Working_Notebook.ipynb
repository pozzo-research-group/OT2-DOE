# %% [markdown]
# # This notebook serves as walkthrough for planning an experiment for creation through the OT2.
# ### The following modules are used and should be in the same directory as this notebook:
# * **CreateSamples** is responsible for calculating sample information, which includes component weight fractions and stock volumes
# * **OT2Commands** is responsible for setting up information to be interpretted and executed by opentrons.
# * **OT2Graphing** contains graphing tools to help visualize and explore parameter spaces.

# %%
import CreateSamples
import OT2Commands as ALH
import OT2Graphing as ographing
from opentrons import simulate, execute, protocol_api

# Would not load
import importlib # for reloading packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
importlib.reload(CreateSamples)
importlib.reload(ALH)
importlib.reload(ographing)
# Out:
# <module 'OT2Graphing' from 'C:\\Users\\Edwin\\Desktop\\OT2-DOE\\Plan and Prepare\\OT2Graphing.py'>

# %% [markdown]
# ## Step 1: Set up the experiment dictionary.
# * The first step to planning an experiment is to load the experiment variables and inputs from a csv file. Every variable should have an input with an acceptable datatype. At the moment this step is done by opening a CSV file in Excel, where the first column is the name of the variable and the adjacent column is the variable value. The default delimitter is (,).
#     * Reading directly as csv is fine but it requires you have all data values in a string so then we can use ast.literal_eval to unpack this and the appropiate datatypes. This forces you \to put marks ('') around each variable value when planning the experiment. NOTE: You still need to place marks around anything inside a dtype i.e components inside a list.
#         * To remove this dependency we can build our own interpreters for our specfic cases such as to not use ast.literal_evals default unpacking.
#     * Loading from excel can be done in a similar manner but is avoided due not having xlrd or openpyxl depdenency native to python, and the opentrons being limited in the packages we can add/update. Hence we default to a CSV.
# * **The experiment dictionary consist of keys being the variable name and the value being the variables value.**

# %%
path = r"C:\Users\Edwin\Desktop\OT2-DOE\Plan and Prepare\Testing Plans\02_25_21_Ouzo_Search.csv"
experiment_csv_dict = CreateSamples.get_experiment_plan(path)

# %% [markdown]
# ## Step 1a Optional: Load custom labware dictionary (Remote Testing)
# * Provide the path to the directory holding all custom labware. This directory should have custom labware .json files you have previously made and tested, read more here: https://support.opentrons.com/en/articles/3136504-creating-custom-labware-definitions
# * The reason we provide this is when working on a device that is not connected to the OT2's Jupyter notebook there is no way to natively use custom labware. So we create a dictionary of custom labware so we can later load into our protocol to primarily simualte and test protocols for execution later once connnected to the OT2's notebook.
#     * When using custom labware on the OT2's notebook it pulls from a folder labeled "labware", which is something built into the Opentrons hardware. It has not been tested if the custom labware dictionary will superceed this directory of custom labware if used on the OT2.

# %%
labware_dir_path = r"C:\Users\Edwin\Desktop\OT2-DOE\Plan and Prepare\Custom Labware"
custom_labware_dict = ALH.custom_labware_dict(labware_dir_path)

# %% [markdown]
# ## Step 2: Select and Create Sampling Space
# * Create sampling space depending on the units of concentration and method of sampling. All information is pulled from the experimental dictionary made in Step 1.
#     * Currently the only sampling method available are simple lattice and random based sampling. There are two potential ways to create samples in a system of n components which currently utilzie the linspaces of concentration.
#         * *Remember the linspace of concentration refers to [minimum concentration, maximum concentration, concentration step size]*
#     * **Case 1 (Completing case):** Specify all but one (in this case the last) component's concentrations, which with the addition of exposing the unity_filter = True, would calculate the the remaining concentraiton values using the information of the last index of all component related variables (i.e. names). This is only meant for units that require unity like volf, wtf, and molf.
#     * **Case 2 (Non-completing case):** Specify all concentration linspaces, not applying any unit based filters, meant for all other non interdepedent units like molarity and mg/mL.
# * Other things to take into consideration: All units must be the same for unity based, but not for non-unity units.

# %%
wtf_sample_canidates = CreateSamples.generate_candidate_lattice_concentrations(experiment_csv_dict, unity_filter=True)
# o
wtf_sample_canidates
# something interesting you can do here is after making these wtf samples you can now apply some random selection
# Out:
#      dppc wtf  dspepeg200 wtf  pfh wtf  ethanol wtf  water wtf
# 0      0.0001        0.000035    0.000     0.000000   0.999865
# 1      0.0001        0.000035    0.000     0.052632   0.947233
# 2      0.0001        0.000035    0.000     0.105263   0.894602
# 3      0.0001        0.000035    0.000     0.157895   0.841970
# 4      0.0001        0.000035    0.000     0.210526   0.789339
# ..        ...             ...      ...          ...        ...
# 375    0.0001        0.000035    0.001     0.736842   0.262023
# 376    0.0001        0.000035    0.001     0.789474   0.209391
# 377    0.0001        0.000035    0.001     0.842105   0.156760
# 378    0.0001        0.000035    0.001     0.894737   0.104128
# 379    0.0001        0.000035    0.001     0.947368   0.051497
#
# [380 rows x 5 columns]

# %% [markdown]
# ## Step 3: Calculate Volumes of Stocks
# * From the concentration values calculated in Step 2, we use those along with stock concentration information to calculate the volume of required for each sample.
#
# * This is where things get less "*general*" each case depending on the number of stocks, common components (i.e. component A in both stock A and B) and other requirements will typically require its own function. Luckily given the commmonality of using data frames this should be quite simple.
# * Currently the only function to calculate volumes in centered around the Ouzo emulsion systems. This system consist of 3 stock with the solvent being ethanol and two pure stocks of ethanol and water.
#
# * Ideally the way volumes should calculated is simply by calculating "*essential information*" given the concentration of component and the systems overall mass or volume. Using this essential information and the concentration unit of the stock, it should call the appropiate function to calcualte the volume. Many issue could arise such as having a molarity and providing a mass so would need to make sure these cases are sorted and reported back

# %%
volume_sample_canidates = CreateSamples.calculate_ouzo_volumes_from_wtf(wtf_sample_canidates, experiment_csv_dict)
volume_sample_canidates
# Out:
#      dppc-ethanol-stock uL  dspepeg2000-ethanol-stock uL  \
# 0                40.000002                     33.267986
# 1                40.000002                     33.267986
# 2                40.000002                     33.267986
# 3                40.000002                     33.267986
# 4                40.000002                     33.267986
# ..                     ...                           ...
# 375              40.000002                     33.267986
# 376              40.000002                     33.267986
# 377              40.000002                     33.267986
# 378              40.000002                     33.267986
# 379              40.000002                     33.267986
#
#      pfh-ethanol-stock uL  ethanol-stock uL  water-stock uL  \
# 0                0.000000        -73.267988      799.892000
# 1                0.000000        -31.612767      757.786737
# 2                0.000000          9.469235      715.681474
# 3                0.000000         49.914780      673.576211
# 4                0.000000         89.655321      631.470947
# ..                    ...               ...             ...
# 375            202.531646        231.028321      209.618316
# 376            202.531646        258.807338      167.513053
# 377            202.531646        285.312365      125.407789
# 378            202.531646        310.572769       83.302526
# 379            202.531646        334.638289       41.197263
#
#      Total Sample Volume uL
# 0                799.892000
# 1                799.441958
# 2                798.418697
# 3                796.758979
# 4                794.394256
# ..                      ...
# 375              716.446270
# 376              702.120024
# 377              686.519788
# 378              669.674929
# 379              651.635186
#
# [380 rows x 6 columns]

# %% [markdown]
# ## Step 4: Create Complete Component Cocentration and Volume Dataframe and Apply Filters

# %%
complete_df = CreateSamples.combine_df(wtf_sample_canidates, volume_sample_canidates) # unfiltered
# complete_df = pd.concat([complete_df], ignore_index=True)
# Step 3: Apply filters through df based logic, currently 4 filters exist (volume, total, general min and general max)

# First filter for pipette volume constraints, optional Volume Restriction to select certain components for filter application ("stock" must be in column name)
complete_df_f1 = CreateSamples.pipette_volume_restriction_df(complete_df, 30, 1000, experiment_csv_dict['Volume Restriction']) # last argument is optional

# Second filter for overall total volume_restriction, call max destination well volume ("Total Sample Volume" must be in column name)
# max_dest_well_volume = ALH.find_max_dest_volume_labware(experiment_csv_dict, custom_labware_dict)
complete_df_f2 = CreateSamples.total_volume_restriction_df(complete_df_f1,800)

#Thrid filter for any general max or min filtering you would like
final_complete_df = complete_df_f2#CreateSamples.general_max_restriction(complete_df_f2, 360, 'pfh-ethanol-stock uL')
final_complete_df
# Out:
#      dppc wtf  dspepeg200 wtf  pfh wtf  ethanol wtf  water wtf  \
# 3      0.0001        0.000035    0.000     0.157895   0.841970
# 4      0.0001        0.000035    0.000     0.210526   0.789339
# 5      0.0001        0.000035    0.000     0.263158   0.736707
# 6      0.0001        0.000035    0.000     0.315789   0.684076
# 7      0.0001        0.000035    0.000     0.368421   0.631444
# ..        ...             ...      ...          ...        ...
# 375    0.0001        0.000035    0.001     0.736842   0.262023
# 376    0.0001        0.000035    0.001     0.789474   0.209391
# 377    0.0001        0.000035    0.001     0.842105   0.156760
# 378    0.0001        0.000035    0.001     0.894737   0.104128
# 379    0.0001        0.000035    0.001     0.947368   0.051497
#
#      dppc-ethanol-stock uL  dspepeg2000-ethanol-stock uL  \
# 3                40.000002                     33.267986
# 4                40.000002                     33.267986
# 5                40.000002                     33.267986
# 6                40.000002                     33.267986
# 7                40.000002                     33.267986
# ..                     ...                           ...
# 375              40.000002                     33.267986
# 376              40.000002                     33.267986
# 377              40.000002                     33.267986
# 378              40.000002                     33.267986
# 379              40.000002                     33.267986
#
#      pfh-ethanol-stock uL  ethanol-stock uL  water-stock uL  \
# 3                0.000000         49.914780      673.576211
# 4                0.000000         89.655321      631.470947
# 5                0.000000        128.618832      589.365684
# 6                0.000000        166.731650      547.260421
# 7                0.000000        203.920303      505.155158
# ..                    ...               ...             ...
# 375            202.531646        231.028321      209.618316
# 376            202.531646        258.807338      167.513053
# 377            202.531646        285.312365      125.407789
# 378            202.531646        310.572769       83.302526
# 379            202.531646        334.638289       41.197263
#
#      Total Sample Volume uL
# 3                796.758979
# 4                794.394256
# 5                791.252504
# 6                787.260059
# 7                782.343449
# ..                      ...
# 375              716.446270
# 376              702.120024
# 377              686.519788
# 378              669.674929
# 379              651.635186
#
# [237 rows x 11 columns]

# %% [markdown]
# ## Step 4a (Optional): Visual

# %%
# %matplotlib qt
ographing.xy_scatter_df_compare(complete_df, final_complete_df, 'ethanol wtf', 'pfh wtf')
# ographing.xy_scatter_df(final_complete_df, 'ethanol wtf', 'pfh molf')

# %% [markdown]
# ## Step 5: Finalize and Call Seperate Concentration and Volume Dataframes

# %%
final_wtf_df = CreateSamples.isolate_common_column(final_complete_df, 'wtf')
final_volume_df = CreateSamples.isolate_common_column(final_complete_df, 'stock')
final_volume_df
# Out:
#      dppc-ethanol-stock uL  dspepeg2000-ethanol-stock uL  \
# 3                40.000002                     33.267986
# 4                40.000002                     33.267986
# 5                40.000002                     33.267986
# 6                40.000002                     33.267986
# 7                40.000002                     33.267986
# ..                     ...                           ...
# 375              40.000002                     33.267986
# 376              40.000002                     33.267986
# 377              40.000002                     33.267986
# 378              40.000002                     33.267986
# 379              40.000002                     33.267986
#
#      pfh-ethanol-stock uL  ethanol-stock uL  water-stock uL
# 3                0.000000         49.914780      673.576211
# 4                0.000000         89.655321      631.470947
# 5                0.000000        128.618832      589.365684
# 6                0.000000        166.731650      547.260421
# 7                0.000000        203.920303      505.155158
# ..                    ...               ...             ...
# 375            202.531646        231.028321      209.618316
# 376            202.531646        258.807338      167.513053
# 377            202.531646        285.312365      125.407789
# 378            202.531646        310.572769       83.302526
# 379            202.531646        334.638289       41.197263
#
# [237 rows x 5 columns]

# %% [markdown]
# ## Step 6 (Optional): Calculate Stock Prep Information

# %%
chem_database_path = r"Chemical Database.xlsx"
stock_prep_df = CreateSamples.calculate_stock_prep_df(experiment_csv_dict, final_volume_df, chem_database_path, buffer_pct=290)
# pd.set_option('display.float_format', lambda x: '%.2e' % x)
stock_prep_df
# so acutally have it print with concentration, just in case you go iver
# Out:
# 36.97200214659444
# 30.749599001960426
#                   dppc-ethanol-stock  L  dspepeg2000-ethanol-stock  L  \
# solute mass g                  0.073944                      0.025742
# solute volume L                0.000000                      0.000000
# solvent mass g                29.182001                     24.270658
# solvent volume L               0.036972                      0.030750
#
#                   pfh-ethanol-stock  L  ethanol-stock  L  water-stock  L
# solute mass g                 0.382640          0.000000        0.000000
# solute volume L               0.000226          0.000000        0.000000
# solvent mass g               76.145365        185.986405      278.513056
# solvent volume L              0.096472          0.235635        0.278513

# %%
def check_for_distribute(list1, min_val, max_val): 
    return(all(max_val >= x >= min_val or x == 0 for x in list1))

# %%
list1 = [10,34,67,3,0]

check_for_distribute(list1, 3,67)
# Out:
# True

# %% [markdown]
# ## Step 7: Set up Ranges for Stocks

# %%
protocol = simulate.get_protocol_api('2.0', extra_labware=custom_labware_dict)
max_vol = 18000 
stock_ranges = ALH.stock_well_ranges(final_volume_df, max_vol) # set up volumes orders
stock_ranges # make sure there is an assertion when number of ranges exceeds number sof well
# Out:
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults
# [[[0, 237]],
#  [[0, 237]],
#  [[0, 201], [201, 237]],
#  [[0, 61], [61, 129], [129, 207], [207, 237]],
#  [[0, 49], [49, 106], [106, 169], [169, 237]]]

# %%
# Step 8: Simulate/Execute

# %%
final_volume_df
# Out:
#      dppc-ethanol-stock uL  dspepeg2000-ethanol-stock uL  \
# 3                40.000002                     33.267986
# 4                40.000002                     33.267986
# 5                40.000002                     33.267986
# 6                40.000002                     33.267986
# 7                40.000002                     33.267986
# ..                     ...                           ...
# 375              40.000002                     33.267986
# 376              40.000002                     33.267986
# 377              40.000002                     33.267986
# 378              40.000002                     33.267986
# 379              40.000002                     33.267986
#
#      pfh-ethanol-stock uL  ethanol-stock uL  water-stock uL
# 3                0.000000         49.914780      673.576211
# 4                0.000000         89.655321      631.470947
# 5                0.000000        128.618832      589.365684
# 6                0.000000        166.731650      547.260421
# 7                0.000000        203.920303      505.155158
# ..                    ...               ...             ...
# 375            202.531646        231.028321      209.618316
# 376            202.531646        258.807338      167.513053
# 377            202.531646        285.312365      125.407789
# 378            202.531646        310.572769       83.302526
# 379            202.531646        334.638289       41.197263
#
# [237 rows x 5 columns]

# %%
# please for the love of a higher power add easier way to call distribute function, and modularize the way we call commands,
# it should be easy since you already have the set up of pipettes and labware seperate from volume handinling commands, jsut need ot make more neater

# %%
protocol = simulate.get_protocol_api('2.0', extra_labware=custom_labware_dict)
loaded_dict = ALH.loading_labware(protocol, experiment_csv_dict) # the protocol above has been modified globally!
info = ALH.pipette_stock_volumes(protocol, loaded_dict, final_volume_df, stock_ranges)
# Out:
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults
# Switching to next stock. This is Stock 0at position 1
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Distributing [40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000 ...
# Transferring [40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000 ...
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F6 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F7 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F8 of Falcon 48 Well Plate 1500 ÂµL on 3 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F6 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F7 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F8 of Falcon 48 Well Plate 1500 ÂµL on 5 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F6 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F7 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F8 of Falcon 48 Well Plate 1500 ÂµL on 6 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 140.00000696720042 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Switching to next stock. This is Stock 1at position 2
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Distributing [40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000 ...
# Transferring [40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000002322400135, 40.000 ...
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 260.0000139344008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 40.000002322400135 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# Dispensing 40.000002322400135 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 2 at 300.0 uL/sec
# ...
# Aspirating 504.4814736842106 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 504.4814736842106 uL into A1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 462.3762105263158 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 462.3762105263158 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 462.3762105263158 uL into A2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 420.2709473684211 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 420.2709473684211 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 420.2709473684211 uL into A3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 378.16568421052636 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 378.16568421052636 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 378.16568421052636 uL into A4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 336.0604210526316 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 336.0604210526316 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 336.0604210526316 uL into A5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 293.95515789473694 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 293.95515789473694 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 293.95515789473694 uL into A6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 251.84989473684223 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 251.84989473684223 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 251.84989473684223 uL into A7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 209.74463157894743 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 209.74463157894743 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 209.74463157894743 uL into A8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 167.63936842105264 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 167.63936842105264 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 167.63936842105264 uL into B1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 125.53410526315797 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 125.53410526315797 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 125.53410526315797 uL into B2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Returning tip
# Dropping tip into E5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from F5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 83.42884210526327 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 83.42884210526327 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 83.42884210526327 uL into B3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Transferring 41.32357894736849 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 41.32357894736849 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 41.32357894736849 uL into B4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Returning tip
# Dropping tip into F5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from F5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 462.33410526315794 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 462.33410526315794 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 462.33410526315794 uL into B5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 420.22884210526325 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 420.22884210526325 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 420.22884210526325 uL into B6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 378.12357894736846 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 378.12357894736846 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 378.12357894736846 uL into B7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 336.01831578947366 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 336.01831578947366 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 336.01831578947366 uL into B8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 293.913052631579 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 293.913052631579 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 293.913052631579 uL into C1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 251.80778947368427 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 251.80778947368427 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 251.80778947368427 uL into C2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 209.7025263157895 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 209.7025263157895 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 209.7025263157895 uL into C3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 167.59726315789473 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 167.59726315789473 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 167.59726315789473 uL into C4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 125.49200000000002 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 125.49200000000002 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 125.49200000000002 uL into C5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Returning tip
# Dropping tip into F5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from G5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 83.38673684210535 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 83.38673684210535 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 83.38673684210535 uL into C6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Transferring 41.28147368421056 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C7 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 41.28147368421056 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 41.28147368421056 uL into C7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Returning tip
# Dropping tip into G5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from G5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 462.2920000000001 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C8 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 462.2920000000001 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 462.2920000000001 uL into C8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 420.1867368421053 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 420.1867368421053 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 420.1867368421053 uL into D1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 378.0814736842106 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 378.0814736842106 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 378.0814736842106 uL into D2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 335.9762105263158 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 335.9762105263158 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 335.9762105263158 uL into D3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 293.8709473684211 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 293.8709473684211 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 293.8709473684211 uL into D4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 251.76568421052642 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 251.76568421052642 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 251.76568421052642 uL into D5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 209.66042105263168 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 209.66042105263168 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 209.66042105263168 uL into D6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 167.55515789473688 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D7 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 167.55515789473688 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 167.55515789473688 uL into D7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 125.44989473684218 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D8 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 125.44989473684218 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 125.44989473684218 uL into D8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Returning tip
# Dropping tip into G5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from H5 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 83.3446315789475 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E1 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 83.3446315789475 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 83.3446315789475 uL into E1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Transferring 41.23936842105272 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 41.23936842105272 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 41.23936842105272 uL into E2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Returning tip
# Dropping tip into H5 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from H5 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 462.2498947368421 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 462.2498947368421 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 462.2498947368421 uL into E3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 420.1446315789474 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 420.1446315789474 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 420.1446315789474 uL into E4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 378.0393684210527 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 378.0393684210527 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 378.0393684210527 uL into E5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 335.9341052631579 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E6 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 335.9341052631579 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 335.9341052631579 uL into E6 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 293.8288421052632 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E7 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 293.8288421052632 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 293.8288421052632 uL into E7 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 251.7235789473685 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E8 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 251.7235789473685 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 251.7235789473685 uL into E8 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 209.61831578947374 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F1 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 209.61831578947374 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 209.61831578947374 uL into F1 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 167.51305263157894 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F2 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 167.51305263157894 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 167.51305263157894 uL into F2 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Transferring 125.40778947368425 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F3 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 125.40778947368425 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 500.0 uL/sec
# Dispensing 125.40778947368425 uL into F3 of Falcon 48 Well Plate 1500 ÂµL on 9 at 1000.0 uL/sec
# Returning tip
# Dropping tip into H5 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A6 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 83.30252631578956 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F4 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 83.30252631578956 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 83.30252631578956 uL into F4 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Transferring 41.19726315789479 from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F5 of Falcon 48 Well Plate 1500 ÂµL on 9
# Aspirating 41.19726315789479 uL from C4 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 150.0 uL/sec
# Dispensing 41.19726315789479 uL into F5 of Falcon 48 Well Plate 1500 ÂµL on 9 at 300.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12

# %%
## Step 9: Uploaded to Google Drive

# %%
CreateSamples.create_csv(r"C:\Users\Edwin\Desktop\test", info['info concat'], final_wtf_df.values, experiment_csv_dict)
df = pd.read_csv(r"C:\Users\Edwin\Desktop\test")
