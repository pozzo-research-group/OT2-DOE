# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# this is all fake data

ethanol = np.arange(0,3.3,0.1)
absorbance =np.sin(ethanol)*0.1
plt.scatter(ethanol, absorbance)

# %%
ethanol = np.arange(0,1,0.05)
absorbance = np.asarray([0.01,0.05,0.1,0.14,0.22,0.34,0.48,0.52,0.54,0.51,0.45,0.40,0.39,0.31,0.27,0.15,0.12,0.11,0.05,0])*0.2
plt.scatter(ethanol, absorbance)

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
plt.scatter(range(len(s)),s)

# %%
len(absorbance)
# Out:
# 10

# %%
fig, ax = plt.subplots(1)
ax.scatter(ethanol,abs_)
ax.set_xlabel('Ethanol wtf')
ax.set_ylabel('AU')
# Out:
# Text(0, 0.5, 'y label')

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()
