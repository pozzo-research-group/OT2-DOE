# %% [markdown]
# * Ouzo_Sampling_Wtf_Lattice_Volume contains all the functions responsible for calculating sample information, which includes component weight fractions and stock volumes.
# * OT2_Ouzo_Commands_API2 contains the commands for the OT2 robot.
# * Ouzo_Graph_Tools contains graphing tools to help visualize and explore parameter spaces.

# %%
import CreateSamples
import OT2_Ouzo_Commands_API2c as ot2_commands
import Ouzo_Graph_Tools as ouzo_graphs
from opentrons import simulate, execute, protocol_api
import os
import pandas as pd
import glob, json
# Out:
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# Loading json containers...
# Json container file load complete, listing database
# Found 0 containers to add. Starting migration...
# Database migration complete!

# %%
import importlib
importlib.reload(CreateSamples)
# Out:
# <module 'CreateSamples' from 'C:\\Users\\Edwin\\Desktop\\OT2Protocols\\ot2protocol\\Ouzo_OT2_Sampling\\CreateSamples.py'>

# %% [markdown]
# #### Creating Samples
# * Sample creation begins with the use of an csv file which contains all the information regarding sample, stock and OT2 specfication.
#     * At the moment, the excel sheet is not very flexible so do not try to stray away with changing the formatting of variables (i.e. variables shown as list should be maintained as list even if there is only one entry - See the provided templete to get started)
# * The csv file can and should be opened in Excel, once opened you should note the three colors:
#     * Green: Absolute requirements in order to create samples and execute commands on the OT2.
#     * Yellow: An optional transfer conducted at the end of the OT2 commands originating from the green variables.
#     * Blue: An optional and independent transer which required its own protocol object, will fail if attempting to run using protocol object tied to green and yellow.

# %% [markdown]
# ## Step 1: Provide the path

# %%
# # path to work from back
# dir_path_back = os.getcwd()
# testing_plans_dir = dir_path_back + '\Testing Plans'
# testing_plan_name = '\\Ouzo_CSV_Templete.csv' # numbers mean \\1 = \1
# final_testing_plan_path = testing_plans_dir+testing_plan_name
# print(final_testing_plan_path, os.path.isfile(final_testing_plan_path))
# path = r"C:\Users\Edwin\Desktop\12_2_2020\12_2_2020_Lipid_Scan.csv"

path = r"C:\Users\Edwin\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\Testing Plans\01_07_2020_Lipid_Trial2_Scan.csv"

# %% [markdown]
# ## Step 2: Parameter Space Explortion:
# * Searching through different stocks is useful in order to find suitable stock canidates. By iterating through a linspace of stocks alongside sample canidates graphs are produced with important information that will help you decided on a suitable group of stocks.
# * The information regarding the iteration through stocks is found in the csv file under the variable:  Stock Concentration [min, max, n]. Another similar vairable listed as just Final Selected Stock Concentrations is used for single exploration and the final concentration used.
# * To select a stock to look into more detail, provide the index number (found on graph). This will allow you to gather and look at the info of this selected stock group to determine things like how much stock you will need to create.
#
# ### Optional: Graphing/Visualization: Will not run on OT2 jupyter notebook
# * This step is useful to see the parameter space you are exploring and whether you need to expand/contract it.
#     * On the right hand side of the provided graph should be information regarding stock and sample information.
#     * It is important to reload in the csv information, once you create your stocks, since most likely the concentration you selected will not be exactly that of what you make (hopefully very close!).
#
# #### Works in progress:
# *  Working on adding the possibility of having a stock be made from other stocks which would be incorperated in the search potentially widening the amount of samples possible.
# * Looking for way to search through more than two components at a time and how to visualize this
#     * This would allow for multiple components to be searched for at once and then start to isolate it to a point where only 2 components are changing.

# %%
import matplotlib.pyplot as plt

# %%
experiment_csv_dict = CreateSamples.get_experiment_plan(path)
wtf_sample_canidates = CreateSamples.generate_candidate_lattice_concentrations(experiment_csv_dict)
wtf_sample_canidates
# Out:
#      dppc molf  dspe-peg molf  PFH molf  ethanol molf  water molf
# 0     0.000000        0.00001     0.001           0.6    0.398990
# 1     0.000071        0.00001     0.001           0.6    0.398919
# 2     0.000143        0.00001     0.001           0.6    0.398847
# 3     0.000214        0.00001     0.001           0.6    0.398776
# 4     0.000286        0.00001     0.001           0.6    0.398704
# ..         ...            ...       ...           ...         ...
# 220   0.000714        0.00100     0.001           0.6    0.397286
# 221   0.000786        0.00100     0.001           0.6    0.397214
# 222   0.000857        0.00100     0.001           0.6    0.397143
# 223   0.000929        0.00100     0.001           0.6    0.397071
# 224   0.001000        0.00100     0.001           0.6    0.397000
#
# [225 rows x 5 columns]

# %%
# x = [i[2] for i in wtf_sample_canidates] # add the option of printing the wtf space prior to calculating values. 
# y = [i[3] for i in wtf_sample_canidates]
# plt.scatter(x,y)

# %%
path = r"C:\Users\Edwin\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\Testing Plans\01_07_2020_Lipid_Trial2_Scan.csv"
experiment_csv_dict = create.get_experiment_plan(path)
wtf_sample_canidates = create.generate_candidate_lattice_concentrations(experiment_csv_dict)


# stock search is only necessary when components in the stocks are important but in certain cases you are not changing the stocks only changing the amount of stock, but fair still useful

min_pipetting_volume = 20
max_pipetting_volume = 1000

stock_unfiltered_sample_wtfs_canidates = create.generate_candidate_lattice_stocks(experiment_csv_dict)
stock_search_dict = create.prepare_stock_search(stock_unfiltered_sample_wtfs_canidates, experiment_csv_dict, wtf_sample_canidates, min_pipetting_volume, max_pipetting_volume)

ouzo_graphs.stock_search_sep(stock_search_dict,experiment_csv_dict, wtf_sample_canidates)
# making samples with zero will cause error cause not within bound
# cange into subplots to prevent this, can do interactive to so text information only when hovering
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f0e6836871f8> in <module>
#       1 path = r"C:\Users\Edwin\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\Testing Plans\01_07_2020_Lipid_Trial2_Scan.csv"
# ----> 2 experiment_csv_dict = create.get_experiment_plan(path)
#       3 wtf_sample_canidates = create.generate_candidate_lattice_concentrations(experiment_csv_dict)
#       4
#       5
#
# NameError: name 'create' is not defined

# %%
index = 4
selected_stock_canidate_component_wtfs = stock_search_dict['stocks_wtf_lists'][index]
selected_stock_canidate_component_volumes = stock_search_dict['stocks_volumes_lists'][index]
selected_stock_text = stock_search_dict['stock_text_info'][index]
ouzo_graphs.graph_canidates(experiment_csv_dict, wtf_sample_canidates, selected_stock_canidate_component_wtfs, additional_text = selected_stock_text)

# %% [markdown]
# ## Step 3: Calculate stock volumes
# * Determine the amount of each stock needed

# %%
create.calculate_stock_volumes(experiment_csv_dict, selected_stock_canidate_component_volumes)
# Out:
# 36.750002133705124 mL of dppc-stock w/ conc of 0.002724647 molarity
# 79.43243355476932 mL of dspe-peg-stock w/ conc of 0.000356443 molarity
# 13.710859427048657 mL of ethanol-PFH-Stock w/ conc of 0.0149199 wtf
# 111.64556962025266 mL of ethanol-stock w/ conc of 1 wtf
# 58.500067500000014 mL of water-stock w/ conc of 1 wtf

# %% [markdown]
# ## Step 4: Input selected stock information and volume constraints to create the experiments info dictionary. - needs to be edited - changing code flow
# * This instructional dictionary will contain the following:
#     * experiment_plan_dict: A dictionary that contains all the information from the csv plan.
#     * wtf_sample_canidates: An array containing the unfiltered sample wtfs (in respective order of component to component list).
#     * volume_sample_canidates: An array containing the unfiltered sample stock volumes
#     * filtered_wtf_samples: An array containing the filtered sample wtfs
#     * volume_sample_canidates: An array containing the filtered sample stock volumes
#
# * Volume constraints (in uL) are for the purpose of preventing a single stock volume from being split up in between multiple transfer. This is important when making ouzo emulsions are the final step of water should be done in one step. Addtionally less trasnfers result in less variability.
# * If you encounter an error such as "max() arg is an empty sequence" or where a called variable is empty, the most likely cause is a result of not creating any suitable samples given the provided variables. Try to change the parameters in the excel sheet or the volume constaints, once you are able to create a dictionary step 2 will help you refine your search!
#
#
# * Once you have selected the appropiate stock, create the stock and input the exact concentrations in the csv file under the variable: Stock Concentration (since mosty likely you will not create a stock concentration exactly matching selection).
# ### The experiment_instruction automatically create the required volumes for the selected input stock! Just call them from the dictionary as the variables: 'volume_sample_canidates'
# #
# * Now you can create the appropiate variables from this stock that will be used in the final protocol: volumes and stock concentrations arrays!
# * You can also restrict the number of samples you create if you are limited on labware.

# %%
# these variables although have the same names when searching for the stocks should now replace those for the actual selectede one. 
experiment_instructions = CreateSamples.experiment_sample_dict(path, min_input_volume=0, max_input_volume=1000)
experiment_csv_dict = experiment_instructions['experiment_plan_dict']
wtf_sample_canidates = experiment_instructions['wtf_sample_canidates']

print(wtf_sample_canidates) # transition to df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4372c8f6fc52> in <module>
#       1 # these variables although have the same names when searching for the stocks should now replace those for the actual selectede one.
# ----> 2 experiment_instructions = CreateSamples.experiment_sample_dict(path, min_input_volume=0, max_input_volume=1000)
#       3 experiment_csv_dict = experiment_instructions['experiment_plan_dict']
#       4 wtf_sample_canidates = experiment_instructions['wtf_sample_canidates']
#       5
#
# ~\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\CreateSamples.py in experiment_sample_dict(experiment_plan_path, min_input_volume, max_input_volume)
#     418     # now filter volume min no max for all but water, but min and max for water - but should not have to input volume should just be based on pipettes
#     419
# --> 420     filtered_wtf_samples, filtered_volume_samples, min_sample_volume, max_sample_volume = filter_samples(wtf_sample_canidates, volume_sample_canidates, min_input_volume, max_input_volume)
#     421
#     422     experiment_info_dict = {'experiment_plan_dict': experiment_plan_dict,
#
# ~\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\CreateSamples.py in filter_samples(wtf_samples_canidates, volume_sample_canidates, min_vol, max_vol)
#     388
#     389     for sample_wtfs, sample_vols in zip(wtf_samples_canidates, volume_sample_canidates):
# --> 390         if check_volumes(sample_vols, min_vol, max_vol) == True: # could say samples_vols[:-1], essentially two checks at once, check from sample_vols[:-1] if min_vol, max_vol =optional - change in funtion, and also if samples_vols[-1]
#     391             filtered_volumes.append(sample_vols)
#     392             filtered_wtf.append(sample_wtfs)
#
# ~\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\CreateSamples.py in check_volumes(sample, min_instrument_vol, max_instrument_vol)
#     370     checker = []
#     371     for vol in sample:
# --> 372         if vol >= min_instrument_vol and vol <= max_instrument_vol or vol==0: # zero added in the case of no volume
#     373             checker.append(1)
#     374         else:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
selected_filtered_wtfs = experiment_instructions['filtered_wtf_samples']
selected_filtered_volumes = experiment_instructions['filtered_volume_samples']


print('number of samples = ' + str(len(selected_filtered_wtfs)))

# %% [markdown]
# ## Step 4a: Add optional blank
# * Using the add_blank function, provide the volume for the blank, in addition to the selected wtfs and volumes for the experiment so they can be appended to the end of the respective array. Blank component information should be added to experiment csv file

# %%
seleted_wtfs_plus_blank, selected_volumes_plus_blank = create.add_blank_sample(selected_filtered_wtfs, selected_filtered_volumes, 800, experiment_csv_dict['Blank Component Concentrations (wtfs)'])
ouzo_graphs.graph_canidates(experiment_csv_dict, wtf_sample_canidates, seleted_wtfs_plus_blank)
# add more useful info in graph

# %% [markdown]
# ## Step 5: Run the OT2 commands
# * Now that a stock and its corresponding volhave been selected run the command code.
# * Future: make it so the can edit stock information and print the amount of stock needed (instructions for stock creation)

# %%
labware_dir_path = r"C:\Users\Edwin\Desktop\OT2Protocols\ot2protocol\Ouzo_OT2_Sampling\Custom Labware"
labware_dict = ot2_commands.custom_labware_dict(labware_dir_path)
# selected_volumes_plus_blank

# %%
protocol = simulate.get_protocol_api('2.0')
# in order to change the dispense and aspiration speed - to match the gen1 (), use command: pipette.flow_rate.aspirate/dispense
command_info = ot2_commands.create_samples(protocol, experiment_csv_dict, selected_volumes_plus_blank, custom_labware_dict=labware_dict) 
# when not enough samples present also make sure to raise errors for things like not inputting enough slots/ len of labware does not equal len of slots
# Out:
# C:\Users\Edwin\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Edwin\.opentrons\robot_settings.json not found. Loading defaults
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into A2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into A3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into A4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into A5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into A6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into A7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into A8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into A9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into A10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into A11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into A12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into B1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into B2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into B3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into B5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into B6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into B7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into B8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into B9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into B10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into B11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into B12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into C1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into C2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into C3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into C4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into C5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into C6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C7 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into C8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into C9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into C10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into C11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into C12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into D1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into D2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into D3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into D4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into D5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into D6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into D7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into D8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into D9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D10 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into D11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into D12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into E1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into E2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into E3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into E4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into E5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into E6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into E7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into E8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into E9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into E10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into E11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to E12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into E12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F1 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into F2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into F3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into F4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into F5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into F6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into F7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into F8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into F9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into F10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into F11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to F12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into F12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into G1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into G2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into G3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G4 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into G5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into G6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G7 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into G7 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into G8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into G9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into G10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into G11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into G12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H1 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into H1 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H2 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into H2 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H3 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into H3 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H4 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into H4 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H5 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into H5 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H6 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into H6 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H7 of Corning 96 Well Plate 360 µL Flat on 2
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H8 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into H8 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H9 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into H9 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H10 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into H10 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H11 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into H11 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H12 of Corning 96 Well Plate 360 µL Flat on 2
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into H12 of Corning 96 Well Plate 360 µL Flat on 2 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into A1 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into A2 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into A3 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into A4 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into A5 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into A6 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into A7 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into A8 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into A9 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A10 of Corning 96 Well Plate 360 µL Flat on 3
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A11 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into A11 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A12 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into A12 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into B1 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into B2 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into B3 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into B4 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into B5 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into B6 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into B7 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into B8 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into B9 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B10 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into B10 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B11 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into B11 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B12 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into B12 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Corning 96 Well Plate 360 µL Flat on 3
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into C2 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into C3 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into C4 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into C5 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 125.0000072575004 uL into C6 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 150.00000870900053 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C7 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 150.00000870900053 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 150.00000870900053 uL into C7 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 175.0000101605006 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C8 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 175.0000101605006 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 175.0000101605006 uL into C8 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 200.00001161200066 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 200.00001161200066 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 200.00001161200066 uL into C9 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 225.00001306350077 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C10 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 225.00001306350077 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 225.00001306350077 uL into C10 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 250.0000145150008 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C11 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 250.0000145150008 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 250.0000145150008 uL into C11 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 275.00001596650094 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C12 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 275.00001596650094 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 275.00001596650094 uL into C12 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 300.00001741800105 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D1 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 300.00001741800105 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 300.00001741800105 uL into D1 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 325.00001886950116 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D2 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 325.00001886950116 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 325.00001886950116 uL into D2 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 350.0000203210012 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D3 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 350.0000203210012 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 350.0000203210012 uL into D3 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Returning tip
# Dropping tip into A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Transferring 0.0 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D4 of Corning 96 Well Plate 360 µL Flat on 3
# Transferring 25.000001451500083 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D5 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 25.000001451500083 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 25.000001451500083 uL into D5 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 50.000002903000166 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D6 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 50.000002903000166 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 50.000002903000166 uL into D6 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 75.00000435450026 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D7 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 75.00000435450026 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 75.00000435450026 uL into D7 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 100.00000580600033 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D8 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 100.00000580600033 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 100.00000580600033 uL into D8 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 125.0000072575004 from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to D9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 125.0000072575004 uL from A1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# ...
# Transferring 278.1985 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.1985 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.1985 uL into G9 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.14849999999996 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G10 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.14849999999996 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.14849999999996 uL into G10 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.09849999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G11 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.09849999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.09849999999994 uL into G11 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.04850000000005 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to G12 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.04850000000005 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.04850000000005 uL into G12 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.699 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H1 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.699 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.699 uL into H1 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.649 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H2 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.649 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.649 uL into H2 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.599 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H3 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.599 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.599 uL into H3 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.54900000000004 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H4 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.54900000000004 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.54900000000004 uL into H4 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.499 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H5 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.499 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.499 uL into H5 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.44899999999996 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H6 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.44899999999996 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.44899999999996 uL into H6 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.399 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H7 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.399 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.399 uL into H7 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.349 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H8 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.349 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.349 uL into H8 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.299 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H9 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.299 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.299 uL into H9 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.249 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H10 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.249 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.249 uL into H10 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.19899999999996 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H11 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.19899999999996 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.19899999999996 uL into H11 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.149 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to H12 of Corning 96 Well Plate 360 µL Flat on 3
# Aspirating 278.149 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.149 uL into H12 of Corning 96 Well Plate 360 µL Flat on 3 at 1.0 speed
# Transferring 278.099 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A1 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.099 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.099 uL into A1 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.049 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A2 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.049 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.049 uL into A2 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.999 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A3 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.999 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.999 uL into A3 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.6495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A4 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.6495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.6495 uL into A4 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.5995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A5 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.5995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.5995 uL into A5 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.5495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A6 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.5495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.5495 uL into A6 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.49949999999995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A7 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.49949999999995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.49949999999995 uL into A7 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.4495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A8 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.4495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.4495 uL into A8 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.3995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A9 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.3995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.3995 uL into A9 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.3495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A10 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.3495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.3495 uL into A10 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.2995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A11 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.2995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.2995 uL into A11 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.24949999999995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to A12 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.24949999999995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.24949999999995 uL into A12 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.19949999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B1 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.19949999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.19949999999994 uL into B1 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.1495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B2 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.1495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.1495 uL into B2 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.0995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B3 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.0995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.0995 uL into B3 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.0495 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B4 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.0495 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.0495 uL into B4 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.9995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B5 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.9995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.9995 uL into B5 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.94949999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B6 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.94949999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.94949999999994 uL into B6 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.6 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B7 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.6 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.6 uL into B7 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.54999999999995 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B8 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.54999999999995 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.54999999999995 uL into B8 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.5 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B9 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.5 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.5 uL into B9 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.45 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B10 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.45 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.45 uL into B10 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.4 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B11 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.4 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.4 uL into B11 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.34999999999997 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to B12 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.34999999999997 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.34999999999997 uL into B12 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.3 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C1 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.3 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.3 uL into C1 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.25000000000006 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C2 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.25000000000006 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.25000000000006 uL into C2 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.2 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C3 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.2 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.2 uL into C3 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.15 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C4 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.15 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.15 uL into C4 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.1 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C5 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.1 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.1 uL into C5 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 278.05 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C6 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 278.05 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 278.05 uL into C6 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.99999999999994 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C7 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.99999999999994 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.99999999999994 uL into C7 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.95000000000005 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C8 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.95000000000005 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.95000000000005 uL into C8 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Transferring 277.9 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C9 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 277.9 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 277.9 uL into C9 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Returning tip
# Dropping tip into E1 of Opentrons 96 Tip Rack 300 µL on 10
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 11
# Transferring 800.0 from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 to C10 of Corning 96 Well Plate 360 µL Flat on 4
# Aspirating 800.0 uL from B1 of 20mLscintillation 12 Well Plate 18000 ÂµL on 1 at 1.0 speed
# Dispensing 800.0 uL into C10 of Corning 96 Well Plate 360 µL Flat on 4 at 1.0 speed
# Dropping tip into A1 of Opentrons Fixed Trash on 12

# %%
protocol1 = simulate.get_protocol_api('2.0')
ot2_commands.simple_independent_transfer(protocol1, dict_1['experiment_plan_dict'])

# %% [markdown]
# ## Step 6: Create a csv file containing all the information of the experiment for storage and future linking

# %%
create.create_csv(r"C:\Users\Edwin\Desktop\test", command_info['command info'], seleted_wtfs_plus_blank, experiment_csv_dict)
df = pd.read_csv(r"C:\Users\Edwin\Desktop\test")
# make it upload to team drive on google and have it so you can pull from there as well.

# %%
df
